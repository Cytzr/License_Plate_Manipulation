# %%
# !pip install ultralytics

# %%
from ultralytics import YOLO

model_v12 = YOLO("yolo12m.pt")

model_v12.train(
    data="C:\Users\dataset\data.yaml",
    epochs=100,
    imgsz=640,
    batch=32,
    lr0=0.01,
    device=0,
    deterministic=True,
    project="C:\Users\project",
    name="YOLO model name",
    save=True
)

# %%
from ultralytics import YOLO

model = YOLO(
    "C:\Users\project\YOLO model name\weights\last.pt"
)

model.train(
    resume=True,
    project="C:\Users\project",
    name="YOLO model name"
)
